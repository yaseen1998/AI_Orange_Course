# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
df = pd.read_csv('credit_score.csv')
print(df.shape)
print(df.info())
string_columns = df.select_dtypes(include=['object']).columns
print(len(string_columns))
df = df.drop(['Name','Customer_ID', 'ID',"SSN"], axis=1)
# Out:
# (100000, 28)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  float64
#  5   SSN                       100000 non-null  float64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  float64
#  10  Num_Credit_Card           100000 non-null  float64
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  float64
# ...

# %%
df_first = df.iloc[:,0:12]
df_second = df.iloc[:,12:24]

summary_stats = df_first.describe().drop('count')
summary_stats_second = df_second.describe().drop('count')

# Create a point plot
plt.figure(figsize=(28, 8))
sns.heatmap(data=summary_stats, annot=True, fmt=".2f", cmap="viridis")
plt.title('Summary Statistics Heatmap')
plt.xticks()
plt.show()

plt.figure(figsize=(28, 8))
sns.heatmap(data=summary_stats_second, annot=True, fmt=".2f", cmap="viridis")
plt.title('Summary Statistics Heatmap')
plt.xticks()
plt.show()

# %%
value_counts = df['Type_of_Loan'].value_counts()

# remove all row No Data  
top_n = 10
other_count = value_counts[top_n:].sum()
top_value_counts = value_counts[:top_n]
top_value_counts['Other'] = other_count

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(top_value_counts, labels=top_value_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Top Unique Loan Types')

plt.axis('equal')
plt.show()

# %%
value_counts = df['Type_of_Loan'].value_counts()
value_counts_df = value_counts.reset_index()
value_counts_df.columns = ['Type_of_Loan', 'Count']

# Create a treemap using plotly
fig = px.treemap(value_counts_df, 
                 path=['Type_of_Loan'], 
                 values='Count', 
                 title='Treemap of Loan Types')

# Show the interactive treemap
fig.show()

# %%
df_string = df.select_dtypes(include=['object'])
print(df_string.columns)
# Out:
# Index(['Occupation', 'Type_of_Loan', 'Credit_Mix', 'Payment_of_Min_Amount',
#        'Payment_Behaviour', 'Credit_Score'],
#       dtype='object')

# %%
df_occupation = df_string['Occupation'].value_counts()
# plot histogram
plt.figure(figsize=(28, 8))
sns.barplot(x=df_occupation.index, y=df_occupation.values,color='orange')
plt.title('Occupation Histogram')
plt.ylabel('Count')
plt.xlabel('Occupation')
plt.show()

# %%
df_Credit_Mix = df_string['Credit_Mix'].value_counts()
# plot histogram
plt.figure(figsize=(28, 8))
sns.barplot(x=df_Credit_Mix.index, y=df_Credit_Mix.values,color='orange')
plt.title('Credit_Mix Histogram')
plt.ylabel('Count')
plt.xlabel('Credit_Mix')
plt.show()

# %%
df_Payment_of_Min_Amount = df_string['Payment_of_Min_Amount'].value_counts()
# plot histogram
plt.figure(figsize=(28, 8))
sns.barplot(x=df_Payment_of_Min_Amount.index, y=df_Payment_of_Min_Amount.values,color='orange')
plt.title('Payment_of_Min_Amount Histogram')
plt.ylabel('Count')
plt.xlabel('Payment_of_Min_Amount')
plt.show()

# %%
df_Payment_Behaviour = df_string['Payment_Behaviour'].value_counts()
# plot histogram
plt.figure(figsize=(28, 8))
sns.barplot(x=df_Payment_Behaviour.index, y=df_Payment_Behaviour.values,color='orange')
plt.title('Payment_Behaviour Histogram')
plt.ylabel('Count')
plt.xlabel('Payment_Behaviour')
plt.show()

# %%
df_Credit_Score = df_string['Credit_Score'].value_counts()
# plot histogram
plt.figure(figsize=(28, 8))
sns.barplot(x=df_Credit_Score.index, y=df_Credit_Score.values,color='orange')
plt.title('Credit_Score Histogram')
plt.ylabel('Count')
plt.xlabel('Credit_Score')
plt.show()
